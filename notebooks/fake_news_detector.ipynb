# %%
import os
os.chdir(r'C:\Users\divya\fake-news-detector')
print("Working directory:", os.getcwd())
print("Files in data folder:", os.listdir('data'))
# Out:
# Working directory: C:\Users\divya\fake-news-detector
# Files in data folder: ['WELFake_Dataset.csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

print("All libraries imported successfully!")
# Out:
# All libraries imported successfully!

# %%
import os
for root, dirs, files in os.walk(r'C:\Users\divya'):
    for file in files:
        if file == 'WELFake_Dataset.csv':
            print(os.path.join(root, file))
# Out:
# C:\Users\divya\OneDrive\Desktop\WELFake_Dataset.csv

# %%
import os
for root, dirs, files in os.walk(r'C:\Users\divya'):
    for file in files:
        if file == 'WELFake_Dataset.csv':
            print(os.path.join(root, file))
# Out:
# C:\Users\divya\OneDrive\Desktop\WELFake_Dataset.csv

# %%
import os
for root, dirs, files in os.walk(r'C:\Users\divya\OneDrive'):
    for file in files:
        if 'WELFake' in file:
            print(os.path.join(root, file))
# Out:
# C:\Users\divya\OneDrive\Desktop\WELFake_Dataset.csv

# %%
import os
import shutil

# Move the file to the data folder
shutil.copy(r'C:\Users\divya\OneDrive\Desktop\WELFake_Dataset.csv', r'C:\Users\divya\fake-news-detector\data\WELFake_Dataset.csv')
print("File copied successfully!")
print("Files in data folder:", os.listdir(r'C:\Users\divya\fake-news-detector\data'))
# Out:
# File copied successfully!
# Files in data folder: ['WELFake_Dataset.csv']

# %%
import os
os.chdir(r'C:\Users\divya\fake-news-detector')
print("Working directory:", os.getcwd())
print("Files in data folder:", os.listdir('data'))
# Out:
# Working directory: C:\Users\divya\fake-news-detector
# Files in data folder: ['WELFake_Dataset.csv']
